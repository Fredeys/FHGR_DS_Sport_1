# %%
from pathlib import Path

data_dir = Path("/Users/frederickurbel/Downloads/polar-user-data-export_7e32ae84-89cf-4c56-b29e-d089feef4207")
print(data_dir)
# Out:
# /Users/frederickurbel/Downloads/polar-user-data-export_7e32ae84-89cf-4c56-b29e-d089feef4207

# %%
json_files = list(data_dir.glob("*.json"))
print(f"{len(json_files)} JSON-Dateien gefunden:")
for f in json_files:
    print(" -", f.name)
# Out:
# 4090 JSON-Dateien gefunden:
#  - activity-2024-01-26-320cd5c7-b056-4234-b0de-7a6f8b35e9af.json
#  - activity-2015-11-27-275dbb71-b116-409e-90bc-a6c959db0d00.json
#  - training-session-2017-07-23-1583301562-43de072a-3dcb-430f-8270-998f8dc78784.json
#  - training-target-2021-06-12-1151094821-d0abb3f9-7ed3-4880-b5d8-7d66a4c9c926.json
#  - activity-2025-06-21-0d786ff5-3f65-44cc-9c18-8fa816dbd891.json
#  - training-session-2024-02-12-7817457335-e5b64fdd-1747-4409-aa77-08b0d5de75b4.json
#  - activity-2021-09-16-b2338595-ad64-4efe-a719-50e609db3cbc.json
#  - activity-2024-07-15-dc31ee69-703b-48b6-a4ec-d4bfd26452be.json
#  - activity-2017-03-30-b7de1c0d-a692-46d3-8743-f39a01cfb268.json
#  - training-session-2023-03-19-7604056696-c943c71d-67ad-4889-98de-fc581455a059.json
#  - activity-2021-11-05-e4bf5098-f33c-4d96-bfd6-4a369eff15a8.json
#  - training-target-2021-06-09-1151094806-1b200c65-af7f-40e0-a8b0-32dda00a36e6.json
#  - activity-2025-05-27-0510e2d8-b5ad-4438-9ce3-9f026a544920.json
# ...

# %%
import json
import pandas as pd
from pathlib import Path

# Ordnerpfad
data_dir = Path("/Users/frederickurbel/Downloads/polar-user-data-export_7e32ae84-89cf-4c56-b29e-d089feef4207")

# Alle activity-*.json Dateien filtern
activity_files = [f for f in data_dir.glob("*.json") if f.name.startswith("activity-")]
print(f"{len(activity_files)} Activity-Dateien gefunden")

# Daten einlesen
activity_rows = []
for file in activity_files:
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
    # Metadata aus Dateiname extrahieren (Datum)
    date_str = file.name.split("-")[1]  # z.B. activity-2024-01-26-...
    activity_rows.append({"filename": file.name, "date": date_str, **data})

df_activity = pd.DataFrame(activity_rows)

# Datum formatieren
df_activity["date"] = pd.to_datetime(df_activity["date"], errors="coerce")

print(df_activity.info())
print(df_activity.head(3))
# Out:
# 3087 Activity-Dateien gefunden
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3087 entries, 0 to 3086
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   filename             3087 non-null   object
#  1   date                 3087 non-null   datetime64[ns]
#  2   exportVersion        3087 non-null   object
#  3   summary              1716 non-null   object
#  4   samples              3087 non-null   object
#  5   physicalInformation  3087 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 144.8+ KB
# None
#                                             filename       date exportVersion  \
# 0  activity-2024-01-26-320cd5c7-b056-4234-b0de-7a... 2024-01-26           2.6
# 1  activity-2015-11-27-275dbb71-b116-409e-90bc-a6... 2015-11-27           2.6
# 2  activity-2025-06-21-0d786ff5-3f65-44cc-9c18-8f... 2025-06-21           2.6
#
# ...

# %%
training_files = [f for f in data_dir.glob("*.json") if f.name.startswith("training-session-")]
print(f"{len(training_files)} Trainings-Dateien gefunden")

training_rows = []
for file in training_files:
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
    date_str = file.name.split("-")[2]  # training-session-2017-07-23-...
    training_rows.append({"filename": file.name, "date": date_str, **data})

df_training = pd.DataFrame(training_rows)
df_training["date"] = pd.to_datetime(df_training["date"], errors="coerce")
print(df_training.head(3))
# Out:
# 780 Trainings-Dateien gefunden
#                                             filename       date exportVersion  \
# 0  training-session-2017-07-23-1583301562-43de072... 2017-01-01           2.6
# 1  training-session-2024-02-12-7817457335-e5b64fd... 2024-01-01           2.6
# 2  training-session-2023-03-19-7604056696-c943c71... 2023-01-01           2.6
#
#      name  deviceId  latitude  longitude                startTime  \
# 0  Laufen  6199C715  47.18995   8.827599  2017-07-23T14:53:26.000
# 1          87FE0E2E       NaN        NaN  2024-02-12T20:14:26.218
# 2          87FE0E2E       NaN        NaN  2023-03-19T17:40:45.489
#
#                   stopTime  timeZoneOffset  ...     duration kiloCalories  \
# 0  2017-07-23T15:58:59.000             120  ...  PT3931.875S        587.0
# 1  2024-02-12T20:44:02.315              60  ...  PT1692.965S        206.0
# 2  2023-03-19T19:12:37.569              60  ...  PT5452.219S        732.0
#
# ...

# %%
# Alle training-target-*.json Dateien einlesen
target_files = [f for f in data_dir.glob("*.json") if f.name.startswith("training-target-")]
print(f"{len(target_files)} Training-Target-Dateien gefunden")

target_rows = []
for file in target_files:
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)
    # training-target-YYYY-MM-DD-...
    date_str = file.name.split("-")[2]  # Index 2 → YYYY
    # Sicherheitshalber Datum als 3 Teile zusammensetzen
    date_parts = file.name.split("-")[2:5]  # YYYY-MM-DD
    date_str = "-".join(date_parts)
    target_rows.append({"filename": file.name, "date": date_str, **data})

df_target = pd.DataFrame(target_rows)
df_target["date"] = pd.to_datetime(df_target["date"], errors="coerce")

print(df_target.head(3))
# Out:
# 112 Training-Target-Dateien gefunden
#                                             filename       date exportVersion  \
# 0  training-target-2021-06-12-1151094821-d0abb3f9... 2021-06-12           2.6
# 1  training-target-2021-06-09-1151094806-1b200c65... 2021-06-09           2.6
# 2  training-target-2021-05-01-1151094601-8ecbd75b... 2021-05-01           2.6
#
#     done                                        description  \
# 0  False
# 1  False  Aufwärmen: 10 Minuten in Zone 1-2.\nAufgabe: 2...
# 2  False
#
#                 name  programRef                startTime  \
# 0      Core-Training  24096896.0  2021-06-12T18:00:00.000
# 1  Mittellanger Lauf  24096896.0  2021-06-09T18:00:00.000
# 2      Core-Training  24096896.0  2021-05-01T18:00:00.000
#
#                                            exercises  nonUserEditable  \
# 0  [{'type': 'FREE', 'duration': 'PT0S', 'sport':...            False
# 1  [{'type': 'PHASED', 'duration': 'PT2400S', 'sp...            False
# ...

# %%
# Alle 247ohr_*.json Dateien finden
ohr_files = [f for f in data_dir.glob("*.json") if f.name.startswith("247ohr_")]
print(f"{len(ohr_files)} 247ohr_-Dateien gefunden")

ohr_rows = []
for file in ohr_files:
    with open(file, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Beispiel: 247ohr_2021_10-xxxx.json → Datum = 2021_10
    date_part = file.name.split("-")[0].replace("247ohr_", "")  # z.B. "2021_10"
    ohr_rows.append({"filename": file.name, "date_raw": date_part, **data})

df_247 = pd.DataFrame(ohr_rows)

# Datum konvertieren (YYYY_MM → Datetime)
if not df_247.empty:
    df_247["date"] = pd.to_datetime(df_247["date_raw"], format="%Y_%m", errors="coerce")

print(df_247.head(3))
# Out:
# 55 247ohr_-Dateien gefunden
#                                             filename date_raw  \
# 0  247ohr_2021_10-57ac3fcc-e24a-4d38-be68-fc7afed...  2021_10
# 1  247ohr_2022_05-1b4dc29b-5128-4809-a903-dca5ef1...  2022_05
# 2  247ohr_2021_05-76192525-61c7-4c6b-b7ec-7b147f3...  2021_05
#
#                                           deviceDays       date
# 0  [{'userId': 10995975, 'deviceId': '87FE0E2E', ... 2021-10-01
# 1  [{'userId': 10995975, 'deviceId': '87FE0E2E', ... 2022-05-01
# 2  [{'userId': 10995975, 'deviceId': '87FE0E2E', ... 2021-05-01

# %%
import os

# Speicherort festlegen (z. B. direkt im Downloads-Ordner)
output_dir = Path("/Users/frederickurbel/Downloads")
os.makedirs(output_dir, exist_ok=True)

# DataFrames speichern
df_activity.to_csv(output_dir / "activity.csv", index=False)
df_training.to_csv(output_dir / "training_session.csv", index=False)
df_target.to_csv(output_dir / "training_target.csv", index=False)
df_247.to_csv(output_dir / "247ohr.csv", index=False)

print(f"CSVs wurden gespeichert in: {output_dir}")
# Out:
# ✅ CSVs wurden gespeichert in: /Users/frederickurbel/Downloads

# %%
import json

# Erste Zeile mal anschauen
import ast
sample = df_247.iloc[0]['deviceDays']
print(type(sample))
print(sample)

# %%
import ast
import pandas as pd

hr_rows = []

for idx, row in df_247.iterrows():
    raw = row['deviceDays']
    if pd.isna(raw) or not isinstance(raw, str) or len(raw) < 10:
        continue
    try:
        days = ast.literal_eval(raw)  # wandelt den JSON-String in Python-Liste um
        for d in days:
            # d ist ein Dictionary mit 'date', 'restingHeartRate', 'averageHeartRate' usw.
            hr_rows.append(d)
    except Exception as e:
        print(f"Fehler beim Parsen in Zeile {idx}: {e}")
        continue

df_hr_daily = pd.DataFrame(hr_rows)
df_hr_daily['date'] = pd.to_datetime(df_hr_daily['date'])
df_hr_daily = df_hr_daily.sort_values('date')

print(df_hr_daily.head())
print(df_hr_daily.columns)

# %%
from pathlib import Path

# 📂 Speicherort definieren – dein Projektordner
output_path = Path.home() / "3_Sem" / "DS_Projekt1" / "df_hr_daily.csv"

# DataFrame als CSV speichern
df_hr_daily.to_csv(output_path, index=False)

print(f"df_hr_daily wurde gespeichert unter:\n{output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 output_path = Path.home() / "3_Sem" / "DS_Projekt1" / "daily_hr.csv"
#       6 # CSV speichern
# ----> 7 daily_hr.to_csv(output_path, index=False)
#       9 print(f"✅ daily_hr.csv wurde gespeichert unter:\n{output_path}")
#
# NameError: name 'daily_hr' is not defined
